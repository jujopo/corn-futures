# %% [markdown]
# # Temperature requirements
#
# Corn can survive to adverse temperatures, such as ranges from 32°F (0°C) to over 112°F (45°C). The growing limits are more restricted, with temperatures ranging from 41°F (5°C) to near 95°F (35°C).
#
# > Optimal temperatures for growth vary between day and night, as well as over the entire growing season; for example, during daylight hours, the optimal ranges between 77°F and 91°F (25°C - 33°C) while night temperatures range between 62°F
